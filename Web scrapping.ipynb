# %%
pip install bs4
# Out:
# ...
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=1d53b03e0f6b96d0b68bcda32d2fb3f71932c033d2eb13f4b4db75c54dd52668
#   Stored in directory: c:\users\karan\appdata\local\pip\cache\wheels\25\42\45\b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

r = requests.get('https://www.flipkart.com/search?q=laptops&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_1_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_1_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=laptops&requestId=480da909-3901-4e11-bdab-400e435e45e0')
print(r)

soup = BeautifulSoup(r.content, 'html.parser')

s = soup.find('div', id='container')
content = s.find_all('p')
 
print(content)
# Out:
# <Response [200]>
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np


LaptopName = []
LaptopRating = []
LaptopSpecs = []
Price = []

url = "https://www.flipkart.com/search?q=laptops&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_1_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_1_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=laptops&requestId=480da909-3901-4e11-bdab-400e435e45e0"
request = requests.get(url).content
soup = BeautifulSoup(request, "html.parser")
data = soup.findAll('a', href=True, attrs={'class': '_1fQZEK'})

for i in data:
    lName = i.find('div', attrs={'class': '_4rR01T'})
    lRating = i.find('div', attrs={'class': '_3LWZlK'})
    
    lPrice = i.find('div', attrs={'class': '_30jeq3 _1_WHN1'})

    LaptopName.append(lName.text)
    LaptopRating.append(lRating.text)
    
    Price.append(lPrice.text)

df = pd.DataFrame({'Laptop Name': LaptopName, 'Rating': LaptopRating, 'Price': Price})
print(df)
df.to_csv('scraping.csv', index=False, encoding='utf-8')
# Out:
#                                           Laptop Name Rating    Price
# 0   HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...    4.3  ₹36,990
# 1   Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...    4.4  ₹37,990
# 2   DELL Inspiron Athlon Dual Core 3050U - (8 GB/2...    4.5  ₹32,999
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...    4.3  ₹34,490
# 4   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...    4.3  ₹42,999
# 5   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...    4.3  ₹36,990
# 6   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...    4.2  ₹39,490
# 7   MSI Modern 14 Ryzen 5 Hexa Core 4500U - (8 GB/...    4.6  ₹45,990
# 8   ASUS Core i3 11th Gen - (8 GB/256 GB SSD/Windo...    4.4  ₹37,990
# 9   Lenovo Core i3 10th Gen - (8 GB/512 GB SSD/Win...    4.6  ₹36,990
# 10  HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/51...    4.5  ₹54,990
# 11  HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/...    4.3  ₹34,990
# ...

# %%
data = pd.read_csv("scraping.csv")
data.head(20)
# Out:
#                                           Laptop Name  Rating    Price
# 0   HP Core i3 11th Gen - (8 GB/256 GB SSD/Windows...     4.3  ₹36,990
# 1   Lenovo IdeaPad 3 Core i3 11th Gen - (8 GB/512 ...     4.4  ₹37,990
# 2   DELL Inspiron Athlon Dual Core 3050U - (8 GB/2...     4.5  ₹32,999
# 3   Lenovo IdeaPad 3 Core i3 10th Gen - (8 GB/256 ...     4.3  ₹34,490
# 4   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...     4.3  ₹42,999
# 5   ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 ...     4.3  ₹36,990
# 6   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...     4.2  ₹39,490
# 7   MSI Modern 14 Ryzen 5 Hexa Core 4500U - (8 GB/...     4.6  ₹45,990
# 8   ASUS Core i3 11th Gen - (8 GB/256 GB SSD/Windo...     4.4  ₹37,990
# 9   Lenovo Core i3 10th Gen - (8 GB/512 GB SSD/Win...     4.6  ₹36,990
# 10  HP Pavilion Ryzen 5 Hexa Core 5600H - (8 GB/51...     4.5  ₹54,990
# 11  HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/...     4.3  ₹34,990
# ...
